# %% [markdown]
# # Automated Continuous Training via Kaggle
# This notebook is automatically pushed and executed by GitHub Actions.
# It clones the GitHub repository, installs dependencies, and runs the `src/train.py` script.

# %%
# !git clone https://github.com/sidthebuilder/Provably-Aligned-AI-Core.git
# %cd Provably-Aligned-AI-Core
# !pip install -r requirements.txt
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "xformers<0.0.27" "trl<0.9.0" peft accelerate bitsandbytes

# %%
# Run the training script!
# !python src/train.py

# %% [markdown]
# ## Training Complete!
# The fine-tuned model has been exported to GGUF format and is available in the Kaggle outputs directory.
